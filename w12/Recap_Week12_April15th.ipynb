# %% [markdown]
# ### Class Recap: Week 12 - April 15th, 2024
#
# ## Topic: Disk Instabilities
#
# ### Summary
# Discussed the kind of physical regimes that could lead to non-linear behavior resulting in disk instabilities.
#
# ### Outline
#
# M&#x307; = constant across the disk ≈ νΣ
# <br>
# ν = α C<sub>s</sub> H
# <br>
# H = C<sub>s</sub> Ω (scale height)
# <br>
# ν = ν<sub>kep</sub> = √(GM/R)
# <br>
# Σ = Σ<sub>0</sub> r/r<sub>0</sub><sup>-P</sup>
# <br>
# T = T<sub>0</sub> r/r<sub>0</sub><sup>-q</sup>
# ; where q = 1/2
# <br>
# M = 2πr<sub>0</sub>r<sub>d</sub>Σ<sub>0</sub> with P = 1 (power law)
# <br>
# Use steady state models travel through systems when energy dissipates in a system.
# <br>
# We care about turbulence: angular momentum transport & growth of solids (* all α are not created equally*)
# <br>
# #### Rayleigh Criterion
# <br>
# d/dr (r<sup>2</sup>)Ω > 0 [for stability] ; where r<sup>2</sup> is radius, Ω angular velocity
# <br>
# Ω α r<sup>-q</sup> ; q = 3/2 for Ω = Ω<sub>kep</sub>
# <br>
# r<sup>2</sup>Ω<sup>'</sup> + 2rΩ > 0 ; Ω<sup>'</sup>α-qr<sup>-q-1</sup>α -qΩ/r
# <br>
# r<sup>2</sup>(-qΩ/r) + 2rΩ > 0
# <br>
# -rqΩ + 2rΩ >0
# <br>
# Ω (2-q)> 0
# <br>
# |q| < 2
# <br>
# [linearly stable]
# <br>
# r̈ = -ΔΦ -2 Ω<sub>0</sub> x (vbar) - Ωbar x (Ωbar x rbar)
# <br>
# Coriolis force - Centrifugal force
# <br>
# X = X<sub>0</sub> sin(kt + φ)
# <br>
# Y = Y<sub>0</sub> cos(kt + φ)
# <br>
#  k -> epicycle frequency
#  <br>
#
# ### Epicycle Frequency
# k<sup>2</sup> = 4Ω<sup>2</sup>+2Ωr (dΩ/dr)
# <br>
# k<sup>2</sup> > 0 -> stability in orbit
# <br>
# for Ω = Ω<sub>kep</sub>
# <br>
# k<sup>2</sup> = 4Ω<sup>2</sup>+2Ωr (-qΩ/r) = 4Ω<sup>2</sup> - 2Ω<sup>2</sup>q = Ω<sup>2</sup>
# <br>
# *for every orbit, you make an epicycle (keplarian case)*
#
# ### What about Magnetic Field?
# Magnetorotational intability **(MRI)**
# <br>
# dp/dt + ∇ · (ρu) = 0
# <br>
# du/dt + (u·∇)u = 1/4πρ (∇xB̅)B̅ - 2Ω<sub>0</sub> x u + 2qΩ<sub>0</sub><sup>2</sup> x  Xhat
# <br>
# Ω<sub>0</sub> α r <sup>-q</sup>
# <br>
# ρ = ρ<sub>0</sub>
# <br>
# β = (0, 0, β<sub>0</sub>)
# <br>
# u = (-0, -q Ω<sub>0</sub> X, 0)
#
# <br>
# u<sub>x</sub> = u<sub>x</sub>'(zt)
# <br>
# u<sub>y</sub> = -q Ω<sub>0</sub> X + v<sub>y</sub>'(zt)
# <br>
# u<sub>z</sub> = u<sub>z</sub>'(zt)
# <br>
# B<sub>x</sub>' = B<sub>x</sub> e<sup>-iωt-kx</sup>
#
# #### The Linearnized Version:
# ∂u<sub>x</sub>/∂t = (B<sub>0</sub>/4πρ<sub>0</sub>) ∂B<sub>x</sub>'/∂z + 2Ω<sub>0</sub> U<sub>y</sub>'
# <br>
# ∂u<sub>y</sub>/∂t = -qΩ<sub>0</sub>  U<sub>x</sub>' = (B<sub>0</sub>/4πρ<sub>0</sub>) ∂B<sub>x</sub>'/∂z - 2Ω<sub>0</sub> U<sub>y</sub>'
# <br>
# ∂B<sub>x</sub>/∂t = B<sub>0</sub>∂u'/∂z ; ∂B<sub>y</sub>/∂t = B<sub>0</sub>∂u<sub>y</sub>'/∂z - qΩ<sub>0</sub> B<sub>x</sub>'
# <br>
# iωU'<sub>x</sub>/∂t = -ikB<sub>0</sub>B'<sub>x</sub>/4πρ<sub>0</sub> + 2Ω<sub>0</sub>V'<sub>y</sub>
#
# <br>
# iωxy' = ikB<sub>0</sub>B'<sub>y</sub>/4πρ<sub>0</sub> + (q-z)Ω<sub>0</sub>U'<sub>y</sub>
# <br>
# iωB'<sub>x</sub> = -ikB<sub>0</sub>V'<sub>x</sub>
# <br>
# iωβ'<sub>y</sub> = -ikB<sub>0</sub>U'<sub>y</sub> - qΩ<sub>0</sub>B'<sub>x</sub>

# %% [markdown]
# ### Dispersion Relationship
# ω<sup>4</sup> - ω<sup>2</sup> [2k<sup>2</sup> v<sub>A</sub><sup>2</sup> + 2(2-q)Ω<sub>0</sub><sup>2</sup>] + k<sup>2</sup> v<sub>A</sub><sup>2</sup> [k<sup>2</sup> v<sub>A</sub><sup>2</sup> - 2q Ω<sub>0</sub><sup>2</sup>] = 0
# <br>
# v<sub>A</sub><sup>2</sup> = B<sub>0</sub><sup>2</sup> / 4πρ<sub>0</sub> ;  ω<sup>2</sup> > 0 for stability
# <br>
# k<sup>2</sup> v<sub>A</sub><sup>2</sup> - 2qΩ<sub>0</sub><sup>2</sup> > 0 ; q > 0
# <br>
# k<sup>2</sup> v<sub>A</sub><sup>2</sup> = 2qΩ<sub>0</sub><sup>2</sup>
# <br>
# k<sup>2</sup> v<sub>A</sub><sup>2</sup> = 3Ω<sub>0</sub><sup>2</sup>
# <br>
# k<sup>crit</sup> = √ 3Ω<sub>0</sub><sup>2</sup> / v<sub>A</sub><sup>2</sup>
# <br>
# L<sub>crit</sub> = 2π / k<sub>crit</sub> ; unstable for k < k<sub>crit</sub>
# <br>
# If your magnetic field grows  -> L<sub>min</sub> > 2H -> MRI is H = C<sub>s</sub> / π
# <br>
# B<sub>0</sub><sup>2</sup> > 12/π ρC<sub>s</sub><sup>2</sup>
# <br>
# P<sub>B</sub> = B<sub>0</sub><sup>2</sup> / 8π ; P<sub>B</sub> = ρC<sub>s</sub><sup>2</sup>
# <br>
# Plasma -> β = P<sub>G</sub> / P<sub>B</sub>
# <br>
# β > 2π<sup>2</sup> / 3
# <br>

# %% [markdown]
# ### In a non-ideal MHD:
#
# $\eta$ - resistivity
# <br>
# growth rate - | ω | $\sim$ √3kv<sub>A</sub> $\sim$ 2π√3v<sub>A</sub> / L
# <br>
# d(ω<sup>2</sup>) / d(kv<sub>A</sub>) = 0
#
#
# #### For Fiduacial model of disk:
# R<sub>em</sub> $\sim$ 1.4x10<sup>12</sup> $\chi$<sub>e</sub>(α/10<sup>-2</sup>)<sup>1/2</sup>(r/1au)<sup>1/3</sup>(T/300k)<sup>1/2</sup>(M<sub>*</sub>/M<sub>.</sub>)<sup>-1/2</sup>
# <br>
# $\chi$<sub>e</sub> > 10<sup>-12</sup> for MRI to operate
# <br>
# only in protoplanetary disks
# <br>
# Baseline temperatures -> T<sub>MRI</sub> > 800-1000K
# <br>
# Gravitational Instability
# <br>
# $\partial$ u / $\partial$ t + (u $\cdot$ $\nabla$) u = - $\nabla$ P / ρ - $\nabla$ P_ - 2Ω x u + 2qΩx $\hat{x}$
# <br>
# [$\omega$ -mΩ(r)]<sup>2</sup> = c<sub>s</sub><sup>2</sup>k<sup>2</sup>-2πGΣ|k| + |k|<sup>2</sup>
# <br>
# Q = c<sub>s</sub>k / πGΣ > 1 for stability (Toomie)
