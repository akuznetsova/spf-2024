# %% [markdown]
# # Class Recap: Week No. 8 - March-18
# ## Topic: Premain Sequence Stars
#
# ## Summary
# ```
# We began with an outline of our midterm exam. We then revised all that encompasses pre main sequence stars which includes:
# How energy is produced, how energy is transported, hydrostatic equilibrium (HSEQ), their properties, conservation of mass,
#  momentum conservation, energy conservation, radiation, convection Schwartzchild criterion, and virial theorem.
# See the outline for further details on each of these topics.
# ```
#
# # Outline
#
# ## Midterm Presentation
#
#  ### Context
# + spacial/timescales
# +  Role/stage in star formation
# + How is it studied (how it is studied. Be broad)
#
# ### Case Study
# + name of region/object
# + tracers, wavelength, facility
# + what was measured
# + what was learned
#
# ## Pre-main sequence stars
# ```
# 1st hydrostatic core
# 2nd hydrostatic core
# ```
#
# $t_{\text{KH}}=\frac{G M_{*}^2}{R_\cdot L_{*}}$
#
# $t_{\text{nuc}} = \epsilon \cdot M_{\star} \cdot \frac{c^2}{L_{\star}}$
#
# ### Energy is produced:
# ```
# MS: fusion
# PMS: gravitational energy
# ```
# ### Energy is transported: (=> L_*)
#
# $L_{*}= 4 \pi R_{*}^2\sigma T^4$
# ```
# PMS: (small stars): convection transport
# MS: radiative transport (diffusion equation)
# ```
#
# ### HSEQ (ish)
# ```
# Thermal energy balances gravitational energy
# ```
#
# ### Properties
#
# $T_{\text{eff}}$, M, R, L,
#
# ### Mass conservation
#
# $dm{r} = 4 \pi r^2 {\rho}{rho} dr$
#
# $\frac{DM}{dr} = 4 \pi r^2 {\rho}{rho}$
#
# $\frac{dr}{dM} = \frac{1}{ 4 \pi r^2 {\rho}{(r)}}$
#
# ### Momentum Conservation ==> HSEQ
#
# $\frac{dP}{dr} = -\frac{G M (r)}{r^2} {\rho}{(r)}$
#
# ### Energy conservation
# ```
# 1st law:
# ```
# $\delta(u) = (\delta){Q} + {\delta{W}}$ #where delta Q is the heat transfer and delta W is the work
#
#
#
# ${dQ} = {\epsilon{dM{dt}}} + {L(M)}{dt} - {L(M + dM){dt}} $
#
#
# $ (\epsilon) - {\frac{dL}{dM}}{dMdt}$
#
#
#
# $dW = -{P{\delta}(dV)}$
#
#
# $ = -{P{\delta(\frac{dv}{dM})}}{dM}$
#
#
# $ = -{P{\delta}{\frac{1}{\rho}}}{dm}$
#
#
# ${\delta}{U}{M(r)} = (\epsilon - {\frac{dL}{dM}}){dMdt} - {P{\delta}}{\frac{1}{\rho}}{dM}$
#
# ${\delta}{U} = (\epsilon - {\frac{dL}{dM}}){\delta}{t} - {P{\delta}}{\frac{1}{\rho}}$
#
# ${\frac {dU}{dt}} = (\epsilon - {\frac{dL}{dM}}) - {P}{\frac{d}{dt}}{\frac{1}{\rho}}$
#
# ${\frac{dL}{dM}} = {\epsilon}{\text{nuc}} + [- {\frac{du}{dt}} - {P}{\frac{d}{dt} {\frac{1}{\rho}}}]$
#
# ${\frac {dL}{dr}} = 4 \pi {r^2}{\rho}{/sigma}_{\text{nuc}} + {...} {\frac{dlgrav}{dM}}$
#
# ### Transport
#
# ${H} = {\frac{L(r)}{4 \pi r^2}} = {\frac{16\sigma}{3}} {\frac{1}{\kappa_{R}}} {\frac{T^3}{\rho}}{\frac{dT}{dr}}$
#
# ### Diffusion approximation
#
# ${\frac {1}{\kappa_{R}}} =\frac{\int^\infty_0 \frac{1}{\kappa_{\nu}} \frac{dB_\nu}{dT}d\nu}{\int \frac{dB_\nu}{dT}d\nu}$
#
#
#
# ${\kappa_{R}} {\propto} {rho^a}{T^b}$
#
# $\nabla_{ad} = {\rho} = {\frac{kT}{\mu {mH}}}$ # Kramer's
#
# ${dP} = [d{\rho}T + {dT{\rho}}]{\frac{h}{\mu mH}}$
#
# ${\frac{d{\rho}}{P}} = {\frac{d{\rho}}{\rho}} + {\frac{dT}{T}}$
#
# $(1 - {\frac{1}{\gamma}}){\frac{dp}{p}} = {\frac{dT}{T}}$
#
# ${\frac{dlnT}{dlnP}} = 1 - {\frac{1}{\gamma}} = {\frac{\gamma - 1}{\gamma}}{\frac{dP}{P}} = {\gamma}{\frac{d\rho}{\rho}}$
#
# ## Convection Schwarzchild criterion
#
# $\nabla_{ad}$ (versus)
# $\nabla_{rad} = {\frac{dlnT}{dlnP}}$
#
# $\nabla_{ad} = {\rho} = {\frac{kT}{\mu {mH}}}$ # Kramer's
#
# $\nabla_{rad} = {\frac{P}{T}}{\frac{dTlndr}{dPlndr}}$
# $ = {\frac{3}{64\pi G \sigma}}{\frac{P}{T}}{\kappa_{R}}{\frac{L(r)}{M(r)}}$
#
# $\nabla_{ad}$ <
# $\nabla_{rad}$ = convection
#
# ## Virial Theorem
#
# $ 2 <KE> + <V> = 0$
#
# $<U> = - {\int}{\frac{G M (r)}{r^2}} dM {\propto} {\frac {GM^2}{R}}$
#
# $\bar{T} = {\frac{\int {T}}{M}}dm$
#
# $<KE> = 3/2 {\int}{\frac{KT}{/mu mH}}dM$
#
# $<KE> = 3/2 {\frac {k \bar {T}}{\mu mH}}$
#
# $\bar{T} = {\frac {\propto}{3}} {\frac {\mu mH}{\kappa}{\frac {M}{R}}}$
#
# ${\frac {L}{4 \pi r^2}} {\propto}{\frac {1}{\kappa_{R}}}{\frac{T^3}{\rho}}{\frac {dT}{dR}}$
#
# $T {\propto} {\frac{M}{R}}$
#
# ${\frac {dT}{dR}} = {\frac{dT}{dM}} \cdot {\frac{dM}{dR}}$
#
# $L {\propto}{\frac {4 \pi r^2}{\kappa_{R}}}{\frac{M}{R}}^3 {\frac{1}{\rho R}}{\cdot}{4 \pi r^2 \rho} {\propto}{\frac{M^3}{\kappa_{R}}},$
# $L {\propto} M^3$
#
# ## Related Resources
# ```
# Below is linked my personal notes which include all graphs from the above outline. Feel free to paste more links if you feel it is udeful and/or relevant to these topics.
#
# https://web.goodnotes.com/s/tKDjtRz2rchtRzFb4MxWYU#page-1
# ```
